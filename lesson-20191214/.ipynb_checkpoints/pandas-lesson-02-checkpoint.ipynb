# %%
import pandas as pd

# %%
df = pd.read_csv('./datafiles/lunch_box.csv')

# %%
df.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %%
# tail 5
df.tail()
# Out:
#       datetime   y week  soldout          name   kcal          remarks  \
# 202  2014-9-24  59    水        1   白身魚のマスタード焼き  408.0              NaN
# 203  2014-9-25  50    木        0       牛カルビ焼き肉  394.0              NaN
# 204  2014-9-26  45    金        0      ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205  2014-9-29  56    月        1      豚肉と玉子の炒め  404.0              NaN
# 206  2014-9-30  40    火        0  鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature
# 202            NaN     NaN       曇             0         24.8
# 203            NaN     NaN       曇             0         25.4
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1
# 205            NaN     NaN      快晴            --         26.6
# 206            NaN     NaN      快晴            --         28.1

# %%
# 确认 当前数据的行 & 列
print(df.shape)
# Out:
# (207, 12)

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=207, step=1)

# %%
df[['datetime', 'name', 'kcal', 'temperature']].head()
# Out:
#      datetime        name  kcal  temperature
# 0  2013-11-18    厚切りイカフライ   NaN         19.8
# 1  2013-11-19     手作りヒレカツ   NaN         17.0
# 2  2013-11-20  白身魚唐揚げ野菜あん   NaN         15.5
# 3  2013-11-21      若鶏ピリ辛焼   NaN         15.2
# 4  2013-11-22    ビッグメンチカツ   NaN         16.1

# %%
df[100:120]
# Out:
#       datetime    y week  soldout            name   kcal       remarks  \
# 100  2014-4-22   78    火        1           マーボ豆腐  382.0           NaN
# 101  2014-4-23   63    水        0         手作りひれかつ  340.0           NaN
# 102  2014-4-24   56    木        1        鶏の照り焼きマヨ  360.0           NaN
# 103  2014-4-25   80    金        0             中華丼    NaN      お楽しみメニュー
# 104  2014-4-28   54    月        0        タンドリーチキン  342.0           NaN
# 105  2014-4-30   97    水        1        豚味噌メンチカツ  368.0           NaN
# 106   2014-5-1   64    木        0           マーボ茄子  415.0           NaN
# 107   2014-5-2   47    金        0           鶏の天ぷら  420.0           NaN
# 108   2014-5-7   88    水        1            肉じゃが  415.0           NaN
# 109   2014-5-8   59    木        0           メンチカツ  405.0           NaN
# 110   2014-5-9   58    金        1        手作りチキンカツ  434.0           NaN
# 111  2014-5-12   73    月        0     きのこソースハンバーグ  400.0           NaN
# 112  2014-5-13   70    火        1     白身魚唐揚げ野菜餡かけ  428.0           NaN
# 113  2014-5-14   64    水        1           メンチカツ  430.0           NaN
# 114  2014-5-15   58    木        1        タンドリーチキン  403.0           NaN
# 115  2014-5-16  126    金        0          ポークカレー    NaN      お楽しみメニュー
# 116  2014-5-19   70    月        1     豚肉と茄子のピリ辛炒め  406.0           NaN
# 117  2014-5-20   71    火        0        鶏の味噌漬け焼き  425.0           NaN
# 118  2014-5-21  104    水        1        チーズハンバーグ  430.0           NaN
# 119  2014-5-22   54    木        1  サーモンのムニエル2色ソース  428.0  料理長のこだわりメニュー
#
#              event  payday weather precipitation  temperature
# 100            NaN     NaN       曇            --         18.8
# 101            NaN     NaN      快晴            --         19.4
# 102            NaN     NaN      晴れ            --         19.9
# 103            NaN     NaN      晴れ            --         20.8
# 104            NaN     NaN      晴れ            --         22.7
# 105            NaN     NaN       雨           0.5         17.5
# 106            NaN     NaN      晴れ            --         24.0
# 107            NaN     NaN      晴れ            --         23.3
# 108            NaN     NaN      晴れ            --         18.9
# 109            NaN     NaN      薄曇            --         21.0
# 110            NaN     1.0      晴れ            --         23.4
# 111            NaN     NaN      薄曇            --         22.7
# 112            NaN     NaN       雨             0         18.6
# 113            NaN     NaN      薄曇            --         26.0
# 114            NaN     NaN       曇            --         19.3
# 115           ママの会     NaN      快晴            --         23.8
# 116  キャリアアップ支援セミナー     NaN       曇            --         22.8
# 117            NaN     NaN      薄曇            --         23.9
# 118            NaN     NaN       雨             6         17.4
# 119            NaN     NaN      雷電             0         19.0

# %%
# 取出特写的某行数据
df.loc[100]
# Out:
# datetime         2014-4-22
# y                       78
# week                     火
# soldout                  1
# name                 マーボ豆腐
# kcal                   382
# remarks                NaN
# event                  NaN
# payday                 NaN
# weather                  曇
# precipitation           --
# temperature           18.8
# Name: 100, dtype: object

# %%
# 取出特写的行和列
df.iloc[[1,2,4],[0,2]]
# Out:
#      datetime week
# 1  2013-11-19    火
# 2  2013-11-20    水
# 4  2013-11-22    金

# %%
# 有条件的选出特定的数据
df[df['kcal'] > 400]
# Out:
#       datetime    y week  soldout          name   kcal       remarks event  \
# 28    2014-1-7  131    火        0  カレー入りソーセージカツ  404.0           NaN   NaN
# 29    2014-1-8  128    水        0        豚肉の生姜焼  462.0           NaN   NaN
# 30    2014-1-9  129    木        1        鶏チリソース  435.0           NaN   NaN
# 31   2014-1-10   87    金        0      手作りロースカツ  440.0           NaN   NaN
# 33   2014-1-15  134    水        0        さんま辛味焼  450.0           NaN   NaN
# ..         ...  ...  ...      ...           ...    ...           ...   ...
# 194  2014-9-10   54    水        0   ぶりレモンペッパー焼き  450.0           NaN   NaN
# 197  2014-9-16   56    火        0      チーズメンチカツ  438.0           NaN   NaN
# 198  2014-9-17   49    水        0      チキンフリカッセ  430.0  料理長のこだわりメニュー  ママの会
# 202  2014-9-24   59    水        1   白身魚のマスタード焼き  408.0           NaN   NaN
# 205  2014-9-29   56    月        1      豚肉と玉子の炒め  404.0           NaN   NaN
#
#      payday weather precipitation  temperature
# 28      NaN      快晴            --          7.3
# 29      NaN       曇            --          9.8
# 30      NaN       曇            --         10.9
# 31      1.0      快晴            --          5.1
# 33      NaN       曇            --          2.9
# ..      ...     ...           ...          ...
# 194     1.0       曇             0         25.0
# 197     NaN      晴れ            --         28.8
# 198     NaN       曇            --         25.0
# 202     NaN       曇             0         24.8
# 205     NaN      快晴            --         26.6
#
# [99 rows x 12 columns]

# %%
df[['datetime', 'name', 'kcal']].query('kcal > 400 and name == "豚肉の生姜焼"')
# Out:
#     datetime    name   kcal
# 29  2014-1-8  豚肉の生姜焼  462.0

# %%
# 删除重复数据
df.drop_duplicates() 
print(df.shape)
# Out:
# (207, 12)

# %%
# 打印出主要的统计数据
df.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %%
df.set_index('datetime', inplace=True)
df.head()
# Out:
#               y week  soldout        name  kcal remarks event  payday weather  \
# datetime
# 2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN      快晴
# 2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN      快晴
# 2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN      快晴
# 2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN      快晴
# 2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN      快晴
#
#            precipitation  temperature
# datetime
# 2013-11-18            --         19.8
# 2013-11-19            --         17.0
# 2013-11-20            --         15.5
# 2013-11-21            --         15.2
# 2013-11-22            --         16.1

# %%
df.index
# Out:
# Index(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21', '2013-11-22',
#        '2013-11-25', '2013-11-26', '2013-11-27', '2013-11-28', '2013-11-29',
#        ...
#        '2014-9-16', '2014-9-17', '2014-9-18', '2014-9-19', '2014-9-22',
#        '2014-9-24', '2014-9-25', '2014-9-26', '2014-9-29', '2014-9-30'],
#       dtype='object', name='datetime', length=207)

# %%
# 统计结果集
df['remarks'].unique()
# Out:
# array([nan, '鶏のレモンペッパー焼（50食）、カレー（42食）', '酢豚（28食）、カレー（85食）', 'お楽しみメニュー',
#        '料理長のこだわりメニュー', '手作りの味', 'スペシャルメニュー（800円）'], dtype=object)

# %%
# 统计结果集
df['weather'].unique()
# Out:
# array(['快晴', '曇', '晴れ', '薄曇', '雨', '雪', '雷電'], dtype=object)

# %%
# 改变某列的 title 数值
df.rename(columns={'y': 'sales'}, inplace=True)
df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature
# datetime
# 2013-11-18      快晴            --         19.8
# 2013-11-19      快晴            --         17.0
# 2013-11-20      快晴            --         15.5
# 2013-11-21      快晴            --         15.2
# 2013-11-22      快晴            --         16.1

# %%
# sales 列按升序排列
df.sort_values(by="sales", ascending=True).head()
# Out:
#            sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-9-22     29    月        0           筑前煮  395.0     NaN   NaN     NaN
# 2014-8-1      38    金        0       豚肉の生姜焼き  380.0     NaN   NaN     NaN
# 2014-8-29     39    金        0     チキンの辛味噌焼き  398.0     NaN   NaN     NaN
# 2014-9-30     40    火        0  鶏肉とカシューナッツ炒め  398.0     NaN   NaN     NaN
# 2014-8-12     40    火        1        厚切ハムカツ  400.0     NaN   NaN     NaN
#
#           weather precipitation  temperature
# datetime
# 2014-9-22      晴れ            --         25.2
# 2014-8-1       薄曇            --         32.7
# 2014-8-29       曇             0         25.1
# 2014-9-30      快晴            --         28.1
# 2014-8-12       雨             0         29.4

# %%
# 多列排序
df.sort_values(['sales', 'temperature'], ascending=False).head()
# Out:
#             sales week  soldout           name  kcal remarks event  payday  \
# datetime
# 2013-12-5     171    木        0    鶏のカッシュナッツ炒め   NaN     NaN   NaN     NaN
# 2013-12-9     165    月        1     ハンバーグデミソース   NaN     NaN   NaN     NaN
# 2013-12-16    160    月        0      カキフライタルタル   NaN     NaN   NaN     NaN
# 2013-12-11    157    水        0           五目御飯   NaN     NaN   NaN     NaN
# 2013-12-10    155    火        0  やわらかロースのサムジョン   NaN     NaN   NaN     1.0
#
#            weather precipitation  temperature
# datetime
# 2013-12-5       快晴            --         13.8
# 2013-12-9        曇            --          9.1
# 2013-12-16      快晴            --         11.3
# 2013-12-11       曇            --         11.0
# 2013-12-10       曇           0.5          7.1

# %%
df.index
# Out:
# Index(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21', '2013-11-22',
#        '2013-11-25', '2013-11-26', '2013-11-27', '2013-11-28', '2013-11-29',
#        ...
#        '2014-9-16', '2014-9-17', '2014-9-18', '2014-9-19', '2014-9-22',
#        '2014-9-24', '2014-9-25', '2014-9-26', '2014-9-29', '2014-9-30'],
#       dtype='object', name='datetime', length=207)

# %%
# 数据格式变更
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')

# %%
df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature
# datetime
# 2013-11-18      快晴            --         19.8
# 2013-11-19      快晴            --         17.0
# 2013-11-20      快晴            --         15.5
# 2013-11-21      快晴            --         15.2
# 2013-11-22      快晴            --         16.1

# %%
# dtype='object' >>> dtype='datetime64[ns]' 数据格式发生变更
df.index
# Out:
# DatetimeIndex(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21',
#                '2013-11-22', '2013-11-25', '2013-11-26', '2013-11-27',
#                '2013-11-28', '2013-11-29',
#                ...
#                '2014-09-16', '2014-09-17', '2014-09-18', '2014-09-19',
#                '2014-09-22', '2014-09-24', '2014-09-25', '2014-09-26',
#                '2014-09-29', '2014-09-30'],
#               dtype='datetime64[ns]', name='datetime', length=207, freq=None)

# %%
# 按照索引顺序重新排列
df.sort_index().head(30)
# Out:
#             sales week  soldout           name   kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0       厚切りイカフライ    NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1        手作りヒレカツ    NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0     白身魚唐揚げ野菜あん    NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1         若鶏ピリ辛焼    NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1       ビッグメンチカツ    NaN     NaN   NaN     NaN
# 2013-11-25    135    月        1           鶏の唐揚    NaN     NaN   NaN     NaN
# 2013-11-26    145    火        0       豚のスタミナ炒め    NaN     NaN   NaN     NaN
# 2013-11-27    140    水        1       ボローニャ風カツ    NaN     NaN   NaN     NaN
# 2013-11-28    151    木        0          ハンバーグ    NaN     NaN   NaN     NaN
# 2013-11-29    116    金        0  タルタルinソーセージカツ    NaN     NaN   NaN     NaN
# 2013-12-02    151    月        1          マーボ豆腐    NaN     NaN   NaN     NaN
# 2013-12-03    153    火        1       厚揚げ豚生姜炒め    NaN     NaN   NaN     NaN
# 2013-12-04    151    水        1   クリームチーズ入りメンチ    NaN     NaN   NaN     NaN
# 2013-12-05    171    木        0    鶏のカッシュナッツ炒め    NaN     NaN   NaN     NaN
# 2013-12-06    134    金        0       手作りロースカツ    NaN     NaN   NaN     NaN
# 2013-12-09    165    月        1     ハンバーグデミソース    NaN     NaN   NaN     NaN
# 2013-12-10    155    火        0  やわらかロースのサムジョン    NaN     NaN   NaN     1.0
# 2013-12-11    157    水        0           五目御飯    NaN     NaN   NaN     NaN
# 2013-12-12    109    木        0           肉じゃが    NaN     NaN   NaN     NaN
# 2013-12-13    111    金        1       タンドリーチキン    NaN     NaN   NaN     NaN
# 2013-12-16    160    月        0      カキフライタルタル    NaN     NaN   NaN     NaN
# 2013-12-17    145    火        0        手作りヒレカツ    NaN     NaN  ママの会     NaN
# 2013-12-18    145    水        1            回鍋肉    NaN     NaN   NaN     NaN
# 2013-12-19    151    木        0        ポーク味噌焼き    NaN     NaN   NaN     NaN
# 2013-12-20    134    金        1      鶏の唐揚げ甘酢あん    NaN     NaN   NaN     NaN
# 2013-12-24    122    火        0      さっくりメンチカツ    NaN     NaN   NaN     NaN
# 2013-12-25    121    水        1      手ごね風ハンバーグ    NaN     NaN   NaN     NaN
# 2013-12-26     80    木        0             酢豚    NaN     NaN   NaN     NaN
# 2014-01-07    131    火        0   カレー入りソーセージカツ  404.0     NaN   NaN     NaN
# 2014-01-08    128    水        0         豚肉の生姜焼  462.0     NaN   NaN     NaN
#
#            weather precipitation  temperature
# datetime
# 2013-11-18      快晴            --         19.8
# 2013-11-19      快晴            --         17.0
# 2013-11-20      快晴            --         15.5
# 2013-11-21      快晴            --         15.2
# 2013-11-22      快晴            --         16.1
# 2013-11-25       曇            --         14.6
# 2013-11-26      快晴            --         17.9
# 2013-11-27      晴れ            --         14.7
# 2013-11-28      薄曇            --         17.7
# 2013-11-29      快晴            --         12.1
# 2013-12-02      快晴            --         13.8
# 2013-12-03      快晴            --         13.9
# 2013-12-04      晴れ            --         13.5
# 2013-12-05      快晴            --         13.8
# 2013-12-06      快晴            --         14.9
# 2013-12-09       曇            --          9.1
# 2013-12-10       曇           0.5          7.1
# 2013-12-11       曇            --         11.0
# 2013-12-12      快晴            --         12.3
# 2013-12-13      快晴            --         13.9
# 2013-12-16      快晴            --         11.3
# 2013-12-17       曇            --         10.8
# 2013-12-18       曇            --          7.8
# 2013-12-19       雨           0.5          6.8
# 2013-12-20       曇            --          8.4
# 2013-12-24      快晴            --         11.5
# 2013-12-25      快晴            --          8.0
# 2013-12-26       曇            --          7.3
# 2014-01-07      快晴            --          7.3
# 2014-01-08       曇            --          9.8

# %%
# 按月计算出平均值
df.resample('M').mean()
# Out:
#                  sales   soldout        kcal  payday  temperature
# datetime
# 2013-11-30  124.600000  0.500000         NaN     NaN    16.060000
# 2013-12-31  139.722222  0.444444         NaN     1.0    10.844444
# 2014-01-31  115.222222  0.611111  427.555556     1.0     8.716667
# 2014-02-28  107.842105  0.526316  420.947368     1.0     7.815789
# 2014-03-31   89.350000  0.450000  382.157895     1.0    12.505000
# 2014-04-30   85.761905  0.476190  360.000000     1.0    18.176190
# 2014-05-31   74.200000  0.550000  419.111111     1.0    22.505000
# 2014-06-30   67.285714  0.333333  423.315789     1.0    25.409524
# 2014-07-31   61.363636  0.454545  397.200000     1.0    29.350000
# 2014-08-31   61.166667  0.333333  403.187500     1.0    30.227778
# 2014-09-30   55.550000  0.300000  408.611111     1.0    25.935000

# %%
# 把 index 数据拆分为两列数据
df['month'] = list(pd.Series(df.index).apply(lambda x: x.month))
df['day'] = list(pd.Series(df.index).apply(lambda x: x.day))

df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day
# datetime
# 2013-11-18      快晴            --         19.8     11   18
# 2013-11-19      快晴            --         17.0     11   19
# 2013-11-20      快晴            --         15.5     11   20
# 2013-11-21      快晴            --         15.2     11   21
# 2013-11-22      快晴            --         16.1     11   22

# %%
# 根据某列数据重新生成新的一列数据
labels = ['上旬', '中旬', '下旬']
df['period'] = pd.cut(list(df['day']),  bins=[0,10,20,31], labels=labels, right=True) # 0<day≦10, 10<day≦20, 20<day≦31

df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
# 确认无效数据 
df.isnull().sum()
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
print(df[df.isnull().any(axis=1)].shape)
df[df.isnull().any(axis=1)].head()
# Out:
# (207, 14)
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
# 无效数据的处理 
df.fillna(value={'payday': 0.0}, inplace=True)
df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     0.0
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     0.0
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     0.0
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     0.0
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     0.0
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
df.isnull().sum()
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 把无效数据删除掉 只是删除掉无效数据的那一行
df.dropna(subset=['kcal'], axis=0, inplace=True)
print(df.shape) 
df.head()
# Out:
# (166, 14)
#             sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-01-07    131    火        0  カレー入りソーセージカツ  404.0     NaN   NaN     0.0
# 2014-01-08    128    水        0        豚肉の生姜焼  462.0     NaN   NaN     0.0
# 2014-01-09    129    木        1        鶏チリソース  435.0     NaN   NaN     0.0
# 2014-01-10     87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     0.0
#
#            weather precipitation  temperature  month  day period
# datetime
# 2014-01-07      快晴            --          7.3      1    7     上旬
# 2014-01-08       曇            --          9.8      1    8     上旬
# 2014-01-09       曇            --         10.9      1    9     上旬
# 2014-01-10      快晴            --          5.1      1   10     上旬
# 2014-01-14      晴れ            --          5.8      1   14     中旬

# %%
df.isnull().sum()
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal               0
# remarks          158
# event            155
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 无效数据的处理2
df['precipitation'] = df['precipitation'].replace('--', 0).astype(float)
print(df['precipitation'].shape)
df.head()
# Out:
#             sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-01-07    131    火        0  カレー入りソーセージカツ  404.0     NaN   NaN     0.0
# 2014-01-08    128    水        0        豚肉の生姜焼  462.0     NaN   NaN     0.0
# 2014-01-09    129    木        1        鶏チリソース  435.0     NaN   NaN     0.0
# 2014-01-10     87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     0.0
#
#            weather  precipitation  temperature  month  day period
# datetime
# 2014-01-07      快晴            0.0          7.3      1    7     上旬
# 2014-01-08       曇            0.0          9.8      1    8     上旬
# 2014-01-09       曇            0.0         10.9      1    9     上旬
# 2014-01-10      快晴            0.0          5.1      1   10     上旬
# 2014-01-14      晴れ            0.0          5.8      1   14     中旬

# %%
print(df['precipitation'].shape)
# Out:
# (166,)

# %%
df.isnull().sum()
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal               0
# remarks          158
# event            155
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 超过 80 的以上的全部替换为 　100
pd.DataFrame(df['sales'].mask(df['sales'] > 80, 100)).head()
# Out:
#             sales
# datetime
# 2014-01-07    100
# 2014-01-08    100
# 2014-01-09    100
# 2014-01-10    100
# 2014-01-14    100

# %%
# 删除某行数据 
# df.drop(['remarks'], axis=1, inplace=True)

print(df.shape)
# Out:
# (166, 14)

# %%
df.head()
# Out:
#             sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-01-07    131    火        0  カレー入りソーセージカツ  404.0     NaN   NaN     0.0
# 2014-01-08    128    水        0        豚肉の生姜焼  462.0     NaN   NaN     0.0
# 2014-01-09    129    木        1        鶏チリソース  435.0     NaN   NaN     0.0
# 2014-01-10     87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     0.0
#
#            weather  precipitation  temperature  month  day period
# datetime
# 2014-01-07      快晴            0.0          7.3      1    7     上旬
# 2014-01-08       曇            0.0          9.8      1    8     上旬
# 2014-01-09       曇            0.0         10.9      1    9     上旬
# 2014-01-10      快晴            0.0          5.1      1   10     上旬
# 2014-01-14      晴れ            0.0          5.8      1   14     中旬

# %%
# 数据统计，有点类似于 sql count
df['weather'].value_counts()
# Out:
# 曇     44
# 晴れ    41
# 快晴    34
# 薄曇    23
# 雨     22
# 雷電     1
# 雪      1
# Name: weather, dtype: int64

# %%
# group by 
df.groupby(['week'])['soldout'].count()
# Out:
# week
# 月    34
# 木    37
# 水    37
# 火    35
# 金    23
# Name: soldout, dtype: int64

# %%
df.groupby(['week']).count()
# Out:
#       sales  soldout  name  kcal  remarks  event  payday  weather  \
# week
# 月        34       34    34    34        0      2      34       34
# 木        37       37    37    37        1      3      37       37
# 水        37       37    37    37        4      2      37       37
# 火        35       35    35    35        1      0      35       35
# 金        23       23    23    23        2      4      23       23
#
#       precipitation  temperature  month  day  period
# week
# 月                34           34     34   34      34
# 木                37           37     37   37      37
# 水                37           37     37   37      37
# 火                35           35     35   35      35
# 金                23           23     23   23      23

# %%
# 多列数据统计
df.groupby(['month', 'period'])['sales'].sum()
# Out:
# month  period
# 1      上旬         475
#        中旬         581
#        下旬        1018
# 2      上旬         725
#        中旬         715
#        下旬         609
# 3      上旬         614
#        中旬         698
#        下旬         369
# 4      上旬         792
#        中旬         344
#        下旬         457
# 5      上旬         316
#        中旬         406
#        下旬         517
# 6      上旬         467
#        中旬         440
#        下旬         311
# 7      上旬         460
#        中旬         277
#        下旬         406
# 8      上旬         288
#        中旬         250
#        下旬         334
# 9      上旬         468
#        中旬         249
#        下旬         234
# Name: sales, dtype: int64

# %%
df.groupby(['month', 'period'])['sales'].count()
# Out:
# month  period
# 1      上旬        4
#        中旬        5
#        下旬        9
# 2      上旬        6
#        中旬        7
#        下旬        6
# 3      上旬        6
#        中旬        8
#        下旬        5
# 4      上旬        8
#        中旬        5
#        下旬        6
# 5      上旬        5
#        中旬        6
#        下旬        7
# 6      上旬        7
#        中旬        7
#        下旬        5
# 7      上旬        8
#        中旬        5
#        下旬        7
# 8      上旬        5
#        中旬        5
#        下旬        6
# 9      上旬        8
#        中旬        5
#        下旬        5
# Name: sales, dtype: int64

# %%
# 前行との差分が欲しい時は .diff() を使う
df['temperature_diff'] = df['temperature'].diff(periods=1)
df[['temperature','temperature_diff']].head()
# Out:
#             temperature  temperature_diff
# datetime
# 2014-01-07          7.3               NaN
# 2014-01-08          9.8               2.5
# 2014-01-09         10.9               1.1
# 2014-01-10          5.1              -5.8
# 2014-01-14          5.8               0.7

# %%
df.shape

# %%
df['temperature_rolling_mean'] = df['temperature'].rolling(window=3).mean()
df[['temperature', 'temperature_diff', 'temperature_rolling_mean']].head()
# Out:
#             temperature  temperature_diff  temperature_rolling_mean
# datetime
# 2014-01-07          7.3               NaN                       NaN
# 2014-01-08          9.8               2.5                       NaN
# 2014-01-09         10.9               1.1                  9.333333
# 2014-01-10          5.1              -5.8                  8.600000
# 2014-01-14          5.8               0.7                  7.266667

# %%
df['temperature_pct_change'] = df['temperature'].pct_change()
df[['temperature', 'temperature_diff', 'temperature_rolling_mean', 'temperature_pct_change']]
# Out:
#             temperature  temperature_diff  temperature_rolling_mean  \
# datetime
# 2014-01-07          7.3               NaN                       NaN
# 2014-01-08          9.8               2.5                       NaN
# 2014-01-09         10.9               1.1                  9.333333
# 2014-01-10          5.1              -5.8                  8.600000
# 2014-01-14          5.8               0.7                  7.266667
# ...                 ...               ...                       ...
# 2014-09-22         25.2               1.6                 24.300000
# 2014-09-24         24.8              -0.4                 24.533333
# 2014-09-25         25.4               0.6                 25.133333
# 2014-09-29         26.6               1.2                 25.600000
# 2014-09-30         28.1               1.5                 26.700000
#
#             temperature_pct_change
# datetime
# 2014-01-07                     NaN
# 2014-01-08                0.342466
# 2014-01-09                0.112245
# 2014-01-10               -0.532110
# 2014-01-14                0.137255
# ...                            ...
# 2014-09-22                0.067797
# 2014-09-24               -0.015873
# 2014-09-25                0.024194
# 2014-09-29                0.047244
# 2014-09-30                0.056391
#
# [166 rows x 4 columns]

# %%
df.dropna(subset=['temperature_diff', 'temperature_rolling_mean', 'temperature_pct_change'], axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# sales                         0
# week                          0
# soldout                       0
# name                          0
# kcal                          0
# remarks                     156
# event                       153
# payday                        0
# weather                       0
# precipitation                 0
# temperature                   0
# month                         0
# day                           0
# period                        0
# temperature_diff              0
# temperature_rolling_mean      0
# temperature_pct_change        0
# dtype: int64

# %%
df.head()
# Out:
#             sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-01-09    129    木        1        鶏チリソース  435.0     NaN   NaN     0.0
# 2014-01-10     87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     0.0
# 2014-01-15    134    水        0        さんま辛味焼  450.0     NaN   NaN     0.0
# 2014-01-16    107    木        0  カレイ唐揚げ野菜あんかけ  415.0     NaN   NaN     0.0
#
#            weather  precipitation  temperature  month  day period  \
# datetime
# 2014-01-09       曇            0.0         10.9      1    9     上旬
# 2014-01-10      快晴            0.0          5.1      1   10     上旬
# 2014-01-14      晴れ            0.0          5.8      1   14     中旬
# 2014-01-15       曇            0.0          2.9      1   15     中旬
# 2014-01-16      快晴            0.0          7.0      1   16     中旬
#
#             temperature_diff  temperature_rolling_mean  temperature_pct_change
# datetime
# 2014-01-09               1.1                  9.333333                0.112245
# 2014-01-10              -5.8                  8.600000               -0.532110
# 2014-01-14               0.7                  7.266667                0.137255
# 2014-01-15              -2.9                  4.600000               -0.500000
# 2014-01-16               4.1                  5.233333                1.413793

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# from matplotlib.font_manager import FontProperties

# %%
df['sales'].plot()

# %%
df.plot(y=['temperature', 'temperature_rolling_mean', 'temperature_pct_change'],  figsize=(16,4), alpha=0.5)
plt.title('Temp change')
# Out:
# Text(0.5, 1.0, 'Temp change')

# %%
df.plot(kind='hist', y='sales' , bins=10, figsize=(16,4), alpha=0.5)

# %%
df.plot(kind='scatter', x='kcal', y='sales')

# %%
df.to_csv('./datafiles/processed_datamart.csv', encoding='utf-8')
